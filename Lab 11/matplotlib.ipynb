# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\Musfique's Folder\Tasu\Lab Tasu/test.csv")
df.head(10)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\PC\AppData\Local\Temp\ipykernel_22988\2813315513.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("C:\Musfique's Folder\Tasu\Lab Tasu/test.csv")
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# ...

# %% [markdown]
# 1. Find the number of rows and columns of the data.

# %%
df.shape
# Out:
# (418, 12)

# %%
df['Survied'] = pd.read_csv("C:\Musfique's Folder\Tasu\Lab Tasu\gender_submission.csv")['Survived']
df.head(10)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\PC\AppData\Local\Temp\ipykernel_22988\1431300983.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df['Survied'] = pd.read_csv("C:\Musfique's Folder\Tasu\Lab Tasu\gender_submission.csv")['Survived']
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# ...

# %%
null_columns  = []
for i in df.columns:
    if df['Cabin'].isnull().any():
        null_columns.append(i)

null_columns
# Out:
# ['PassengerId',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked',
#  'Survied']

# %%
test = list(df.columns[df.isna().any()])
test
# Out:
# ['Age', 'Fare', 'Cabin']

# %%
df[df['Cabin'].isnull() == True]
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 412         1304       3                Henriksson, Miss. Jenny Lovisa
# 413         1305       3                            Spector, Mr. Woolf
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked  \
# ...
