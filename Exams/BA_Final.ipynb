# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\Musfique's Folder\Tasu\Lab Tasu/test.csv")
df.head(10)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\PC\AppData\Local\Temp\ipykernel_19276\2813315513.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("C:\Musfique's Folder\Tasu\Lab Tasu/test.csv")
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# 1  47.0      1      0     363272   7.0000   NaN        S
# 2  62.0      0      0     240276   9.6875   NaN        Q
# 3  27.0      0      0     315154   8.6625   NaN        S
# 4  22.0      1      1    3101298  12.2875   NaN        S
# 5  14.0      0      0       7538   9.2250   NaN        S
# 6  30.0      0      0     330972   7.6292   NaN        Q
# 7  26.0      1      1     248738  29.0000   NaN        S
# 8  18.0      0      0       2657   7.2292   NaN        C
# 9  21.0      2      0  A/4 48871  24.1500   NaN        S

# %% [markdown]
# ## **1. Find the number of rows and columns of the data.**

# %%
df.shape
# Out:
# (418, 11)

# %%
df['Survied'] = pd.read_csv("C:\Musfique's Folder\Tasu\Lab Tasu\gender_submission.csv")['Survived']
df.head(10)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\PC\AppData\Local\Temp\ipykernel_19276\1431300983.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df['Survied'] = pd.read_csv("C:\Musfique's Folder\Tasu\Lab Tasu\gender_submission.csv")['Survived']
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked  Survied
# 0  34.5      0      0     330911   7.8292   NaN        Q        0
# 1  47.0      1      0     363272   7.0000   NaN        S        1
# 2  62.0      0      0     240276   9.6875   NaN        Q        0
# 3  27.0      0      0     315154   8.6625   NaN        S        0
# 4  22.0      1      1    3101298  12.2875   NaN        S        1
# 5  14.0      0      0       7538   9.2250   NaN        S        0
# 6  30.0      0      0     330972   7.6292   NaN        Q        1
# 7  26.0      1      1     248738  29.0000   NaN        S        0
# 8  18.0      0      0       2657   7.2292   NaN        C        1
# 9  21.0      2      0  A/4 48871  24.1500   NaN        S        0

# %% [markdown]
# ## **2. (a) Make a list of columns that have missing values.**

# %%
null_columns  = []
for i in df.columns:
    if df['Cabin'].isnull().any():
        null_columns.append(i)

null_columns
# Out:
# ['PassengerId',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked',
#  'Survied']

# %%
test = list(df.columns[df.isna().any()])
test
# Out:
# ['Age', 'Fare', 'Cabin']

# %%
df[df['Cabin'].isnull() == False]
# Out:
#      PassengerId  Pclass                                               Name  \
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# 28           920       1                            Brady, Mr. John Bertram
# ..           ...     ...                                                ...
# 404         1296       1                       Frauenthal, Mr. Isaac Gerald
# 405         1297       2       Nourney, Mr. Alfred (Baron von Drachstedt")"
# 407         1299       1                         Widener, Mr. George Dunton
# 411         1303       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
#
#         Sex   Age  SibSp  Parch         Ticket      Fare            Cabin  \
# 12   female  23.0      1      0          21228   82.2667              B45
# 14   female  47.0      1      0    W.E.P. 5734   61.1750              E31
# 24   female  48.0      1      3       PC 17608  262.3750  B57 B59 B63 B66
# 26   female  22.0      0      1         113509   61.9792              B36
# 28     male  41.0      0      0         113054   30.5000              A21
# ..      ...   ...    ...    ...            ...       ...              ...
# 404    male  43.0      1      0          17765   27.7208              D40
# 405    male  20.0      0      0  SC/PARIS 2166   13.8625              D38
# 407    male  50.0      1      1         113503  211.5000              C80
# 411  female  37.0      1      0          19928   90.0000              C78
# 414  female  39.0      0      0       PC 17758  108.9000             C105
#
#     Embarked  Survied
# 12         S        1
# 14         S        1
# 24         C        1
# 26         C        1
# 28         S        0
# ..       ...      ...
# 404        C        0
# 405        C        0
# 407        C        0
# 411        Q        1
# 414        C        1
#
# [91 rows x 12 columns]

# %%
df[df['Age'].isnull() == True]
# Out:
#      PassengerId  Pclass                                               Name  \
# 10           902       3                                   Ilieff, Mr. Ylio
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 29           921       3                                  Samaan, Mr. Elias
# 33           925       3  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"
# 36           928       3                                Roth, Miss. Sarah A
# ..           ...     ...                                                ...
# 408         1300       3                    Riordan, Miss. Johanna Hannah""
# 410         1302       3                             Naughton, Miss. Hannah
# 413         1305       3                                 Spector, Mr. Woolf
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked  Survied
# 10     male  NaN      0      0      349220   7.8958   NaN        S        0
# 22   female  NaN      0      0    PC 17598  31.6833   NaN        S        1
# 29     male  NaN      2      0        2662  21.6792   NaN        C        0
# 33   female  NaN      1      2  W./C. 6607  23.4500   NaN        S        1
# 36   female  NaN      0      0      342712   8.0500   NaN        S        1
# ..      ...  ...    ...    ...         ...      ...   ...      ...      ...
# 408  female  NaN      0      0      334915   7.7208   NaN        Q        1
# 410  female  NaN      0      0      365237   7.7500   NaN        Q        1
# 413    male  NaN      0      0   A.5. 3236   8.0500   NaN        S        0
# 416    male  NaN      0      0      359309   8.0500   NaN        S        0
# 417    male  NaN      1      1        2668  22.3583   NaN        C        0
#
# [86 rows x 12 columns]

# %%
df[df['Fare'].isnull() == True]
# Out:
#      PassengerId  Pclass                Name   Sex   Age  SibSp  Parch Ticket  \
# 152         1044       3  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#      Fare Cabin Embarked  Survied
# 152   NaN   NaN        S        0

# %% [markdown]
# ## **2. (b) Handle the missing data in whatever manner that makes sense to you.**

# %% [markdown]
# # Handleing NaN of 'Age' column

# %%
meanAge_ = df.copy().groupby(['Pclass', 'Sex'])['Age'].count()
meanAge_
# Out:
# Pclass  Sex
# 1       female    48
#         male      50
# 2       female    29
#         male      59
# 3       female    50
#         male      96
# Name: Age, dtype: int64

# %% [markdown]
# 1. Handled the missing values with mean values of the groups accourding to Pclass and gender.
# 2. Above code shows there are 6 gropus. We calculated the means of each groups and replaced the NaNs of those groups with them.

# %%
meanAge = df.groupby(['Pclass', 'Sex'])['Age'].transform('mean')
df['Age'] = df['Age'].fillna(meanAge)
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex        Age  SibSp  Parch              Ticket      Fare Cabin  \
# 0      male  34.500000      0      0              330911    7.8292   NaN
# 1    female  47.000000      1      0              363272    7.0000   NaN
# 2      male  62.000000      0      0              240276    9.6875   NaN
# 3      male  27.000000      0      0              315154    8.6625   NaN
# 4    female  22.000000      1      1             3101298   12.2875   NaN
# ..      ...        ...    ...    ...                 ...       ...   ...
# 413    male  24.525104      0      0           A.5. 3236    8.0500   NaN
# 414  female  39.000000      0      0            PC 17758  108.9000  C105
# 415    male  38.500000      0      0  SOTON/O.Q. 3101262    7.2500   NaN
# 416    male  24.525104      0      0              359309    8.0500   NaN
# 417    male  24.525104      1      1                2668   22.3583   NaN
#
#     Embarked  Survied
# 0          Q        0
# 1          S        1
# 2          Q        0
# 3          S        0
# 4          S        1
# ..       ...      ...
# 413        S        0
# 414        C        1
# 415        S        0
# 416        S        0
# 417        C        0
#
# [418 rows x 12 columns]

# %% [markdown]
# Checking if any NaN left

# %%
df[df['Age'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Survied]
# Index: []

# %% [markdown]
# # Handleing NaN of 'Fare' column

# %% [markdown]
# Group-Specific Fill: If you want to fill NaN values within groups (e.g., based on a specific column value), you can use groupby() along with fillna()

# %%
fare_group = df.groupby(['Pclass', 'SibSp', 'Parch'])['Fare'].count()
fare_group
# Out:
# Pclass  SibSp  Parch
# 1       0      0         51
#                1          8
#                2          2
#         1      0         26
#                1         11
#                2          2
#                3          2
#                4          1
#         2      0          2
#                2          1
#         3      2          1
# 2       0      0         54
#                1          2
#                2          5
#                3          1
#         1      0         16
#                1          7
#                2          4
#         2      0          2
#                1          2
# 3       0      0        147
#                1          4
#                2          7
#                4          1
#         1      0         18
#                1         15
#                2          4
#                5          1
#                6          1
#                9          2
#         2      0          6
#                2          1
#         3      0          1
#                1          2
#         4      1          1
#                2          3
#         5      2          1
#         8      2          2
# Name: Fare, dtype: int64

# %%
fare_group.shape
# Out:
# (38,)

# %% [markdown]
# 1. Handled the missing values with mean values of the groups accourding to Pclass, SibSp and Parch.
# 2. Above code shows there are 38 gropus. We see that this groups has common fairs, so we replaced the NaNs of those groups with thst common fare.

# %%
df['Fare'] = df.groupby(['Pclass', 'SibSp', 'Parch'])['Fare'].fillna(method='ffill')
df
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_19276\2429844514.py:1: FutureWarning: SeriesGroupBy.fillna is deprecated and will be removed in a future version. Use obj.ffill() or obj.bfill() for forward or backward filling instead. If you want to fill with a single value, use Series.fillna instead
#   df['Fare'] = df.groupby(['Pclass', 'SibSp', 'Parch'])['Fare'].fillna(method='ffill')
# C:\Users\PC\AppData\Local\Temp\ipykernel_19276\2429844514.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Fare'] = df.groupby(['Pclass', 'SibSp', 'Parch'])['Fare'].fillna(method='ffill')
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex        Age  SibSp  Parch              Ticket      Fare Cabin  \
# 0      male  34.500000      0      0              330911    7.8292   NaN
# 1    female  47.000000      1      0              363272    7.0000   NaN
# 2      male  62.000000      0      0              240276    9.6875   NaN
# 3      male  27.000000      0      0              315154    8.6625   NaN
# 4    female  22.000000      1      1             3101298   12.2875   NaN
# ..      ...        ...    ...    ...                 ...       ...   ...
# 413    male  24.525104      0      0           A.5. 3236    8.0500   NaN
# 414  female  39.000000      0      0            PC 17758  108.9000  C105
# 415    male  38.500000      0      0  SOTON/O.Q. 3101262    7.2500   NaN
# 416    male  24.525104      0      0              359309    8.0500   NaN
# 417    male  24.525104      1      1                2668   22.3583   NaN
#
#     Embarked  Survied
# 0          Q        0
# 1          S        1
# 2          Q        0
# 3          S        0
# 4          S        1
# ..       ...      ...
# 413        S        0
# 414        C        1
# 415        S        0
# 416        S        0
# 417        C        0
#
# [418 rows x 12 columns]

# %% [markdown]
# Cheking if any NaN is left

# %%
df.iloc[152]
# Out:
# PassengerId                  1044
# Pclass                          3
# Name           Storey, Mr. Thomas
# Sex                          male
# Age                          60.5
# SibSp                           0
# Parch                           0
# Ticket                       3701
# Fare                       7.8958
# Cabin                         NaN
# Embarked                        S
# Survied                         0
# Name: 152, dtype: object

# %%
df[df['Fare'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Survied]
# Index: []

# %% [markdown]
# # Handleing NaN values of 'Cabin' column
