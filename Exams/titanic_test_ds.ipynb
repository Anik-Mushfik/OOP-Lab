# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\Musfique's Folder\Tasu\Lab Tasu/test.csv")
df.head(10)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\PC\AppData\Local\Temp\ipykernel_23392\2813315513.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("C:\Musfique's Folder\Tasu\Lab Tasu/test.csv")
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# 1  47.0      1      0     363272   7.0000   NaN        S
# 2  62.0      0      0     240276   9.6875   NaN        Q
# 3  27.0      0      0     315154   8.6625   NaN        S
# 4  22.0      1      1    3101298  12.2875   NaN        S
# 5  14.0      0      0       7538   9.2250   NaN        S
# 6  30.0      0      0     330972   7.6292   NaN        Q
# 7  26.0      1      1     248738  29.0000   NaN        S
# 8  18.0      0      0       2657   7.2292   NaN        C
# 9  21.0      2      0  A/4 48871  24.1500   NaN        S

# %% [markdown]
# # **1. Find the number of rows and columns of the data.**

# %%
df.shape
# Out:
# (418, 11)

# %% [markdown]
# # **2. (a) Make a list of columns that have missing values.**

# %%
null_columns  = []
for i in df.columns:
    if df['Cabin'].isnull().any():
        null_columns.append(i)

null_columns
# Out:
# ['PassengerId',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df.isna().any()
# Out:
# PassengerId    False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin           True
# Embarked       False
# dtype: bool

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
test = list(df.columns[df.isna().any()])
test
# Out:
# ['Age', 'Fare', 'Cabin']

# %%
df[df['Cabin'].isnull() == True]
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 412         1304       3                Henriksson, Miss. Jenny Lovisa
# 413         1305       3                            Spector, Mr. Woolf
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# 0      male  34.5      0      0              330911   7.8292   NaN        Q
# 1    female  47.0      1      0              363272   7.0000   NaN        S
# 2      male  62.0      0      0              240276   9.6875   NaN        Q
# 3      male  27.0      0      0              315154   8.6625   NaN        S
# 4    female  22.0      1      1             3101298  12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...      ...   ...      ...
# 412  female  28.0      0      0              347086   7.7750   NaN        S
# 413    male   NaN      0      0           A.5. 3236   8.0500   NaN        S
# 415    male  38.5      0      0  SOTON/O.Q. 3101262   7.2500   NaN        S
# 416    male   NaN      0      0              359309   8.0500   NaN        S
# 417    male   NaN      1      1                2668  22.3583   NaN        C
#
# [327 rows x 11 columns]

# %%
df[df['Age'].isnull() == True]
# Out:
#      PassengerId  Pclass                                               Name  \
# 10           902       3                                   Ilieff, Mr. Ylio
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 29           921       3                                  Samaan, Mr. Elias
# 33           925       3  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"
# 36           928       3                                Roth, Miss. Sarah A
# ..           ...     ...                                                ...
# 408         1300       3                    Riordan, Miss. Johanna Hannah""
# 410         1302       3                             Naughton, Miss. Hannah
# 413         1305       3                                 Spector, Mr. Woolf
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 10     male  NaN      0      0      349220   7.8958   NaN        S
# 22   female  NaN      0      0    PC 17598  31.6833   NaN        S
# 29     male  NaN      2      0        2662  21.6792   NaN        C
# 33   female  NaN      1      2  W./C. 6607  23.4500   NaN        S
# 36   female  NaN      0      0      342712   8.0500   NaN        S
# ..      ...  ...    ...    ...         ...      ...   ...      ...
# 408  female  NaN      0      0      334915   7.7208   NaN        Q
# 410  female  NaN      0      0      365237   7.7500   NaN        Q
# 413    male  NaN      0      0   A.5. 3236   8.0500   NaN        S
# 416    male  NaN      0      0      359309   8.0500   NaN        S
# 417    male  NaN      1      1        2668  22.3583   NaN        C
#
# [86 rows x 11 columns]

# %%
df[df['Fare'].isnull() == True]
# Out:
#      PassengerId  Pclass                Name   Sex   Age  SibSp  Parch Ticket  \
# 152         1044       3  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#      Fare Cabin Embarked
# 152   NaN   NaN        S

# %% [markdown]
# # **2. (b) Handle the missing data in whatever manner that makes sense to you.**

# %% [markdown]
# ## Handleing NaN of 'Age' column

# %%
meanAge_ = df.copy().groupby(['Pclass', 'Sex'])['Age'].count()
meanAge_
# Out:
# Pclass  Sex
# 1       female    48
#         male      50
# 2       female    29
#         male      59
# 3       female    50
#         male      96
# Name: Age, dtype: int64

# %% [markdown]
# 1. Handled the missing values with mean values of the groups accourding to Pclass and gender.
# 2. Above code shows there are 6 gropus. We calculated the means of each groups and replaced the NaNs of those groups with them.

# %%
meanAge = df.groupby(['Pclass', 'Sex'])['Age'].transform('mean')
df['Age'] = df['Age'].fillna(meanAge)
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex        Age  SibSp  Parch              Ticket      Fare Cabin  \
# 0      male  34.500000      0      0              330911    7.8292   NaN
# 1    female  47.000000      1      0              363272    7.0000   NaN
# 2      male  62.000000      0      0              240276    9.6875   NaN
# 3      male  27.000000      0      0              315154    8.6625   NaN
# 4    female  22.000000      1      1             3101298   12.2875   NaN
# ..      ...        ...    ...    ...                 ...       ...   ...
# 413    male  24.525104      0      0           A.5. 3236    8.0500   NaN
# 414  female  39.000000      0      0            PC 17758  108.9000  C105
# 415    male  38.500000      0      0  SOTON/O.Q. 3101262    7.2500   NaN
# 416    male  24.525104      0      0              359309    8.0500   NaN
# 417    male  24.525104      1      1                2668   22.3583   NaN
#
#     Embarked
# 0          Q
# 1          S
# 2          Q
# 3          S
# 4          S
# ..       ...
# 413        S
# 414        C
# 415        S
# 416        S
# 417        C
#
# [418 rows x 11 columns]

# %% [markdown]
# Checking if any NaN left

# %%
df[df['Age'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ## Handleing NaN of 'Fare' column

# %% [markdown]
# Group-Specific Fill: If you want to fill NaN values within groups (e.g., based on a specific column value), you can use groupby() along with fillna()

# %%
df['Fare'].unique().shape
# Out:
# (170,)

# %%
df_copy = df.copy()
df_copy["Count"] = df_copy.index
fare_group = df_copy.groupby([ 'Fare'])['Count'].count()
fare_group = pd.DataFrame(fare_group)
fare_group
# Out:
#           Count
# Fare
# 0.0000        2
# 3.1708        1
# 6.4375        2
# 6.4958        1
# 6.9500        1
# ...         ...
# 227.5250      1
# 247.5208      1
# 262.3750      5
# 263.0000      2
# 512.3292      1
#
# [169 rows x 1 columns]

# %%
df['Fare'].dtype
# Out:
# dtype('float64')

# %%
fare_group.shape
# Out:
# (169, 1)

# %% [markdown]
# 1. Handled the missing values with mean values of the groups accourding to Pclass, SibSp and Parch.
# 2. Above code shows there are 38 gropus. We see that this groups has common fairs, so we replaced the NaNs of those groups with thst common fare.

# %%
df['Fare'] = df.groupby(['Pclass', 'SibSp', 'Parch'])['Fare'].fillna(method='ffill')
df
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_23392\2429844514.py:1: FutureWarning: SeriesGroupBy.fillna is deprecated and will be removed in a future version. Use obj.ffill() or obj.bfill() for forward or backward filling instead. If you want to fill with a single value, use Series.fillna instead
#   df['Fare'] = df.groupby(['Pclass', 'SibSp', 'Parch'])['Fare'].fillna(method='ffill')
# C:\Users\PC\AppData\Local\Temp\ipykernel_23392\2429844514.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Fare'] = df.groupby(['Pclass', 'SibSp', 'Parch'])['Fare'].fillna(method='ffill')
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex        Age  SibSp  Parch              Ticket      Fare Cabin  \
# 0      male  34.500000      0      0              330911    7.8292   NaN
# 1    female  47.000000      1      0              363272    7.0000   NaN
# 2      male  62.000000      0      0              240276    9.6875   NaN
# 3      male  27.000000      0      0              315154    8.6625   NaN
# 4    female  22.000000      1      1             3101298   12.2875   NaN
# ..      ...        ...    ...    ...                 ...       ...   ...
# 413    male  24.525104      0      0           A.5. 3236    8.0500   NaN
# 414  female  39.000000      0      0            PC 17758  108.9000  C105
# 415    male  38.500000      0      0  SOTON/O.Q. 3101262    7.2500   NaN
# 416    male  24.525104      0      0              359309    8.0500   NaN
# 417    male  24.525104      1      1                2668   22.3583   NaN
#
#     Embarked
# 0          Q
# 1          S
# 2          Q
# 3          S
# 4          S
# ..       ...
# 413        S
# 414        C
# 415        S
# 416        S
# 417        C
#
# [418 rows x 11 columns]

# %% [markdown]
# Cheking if any NaN is left

# %%
df.iloc[152]
# Out:
# PassengerId                  1044
# Pclass                          3
# Name           Storey, Mr. Thomas
# Sex                          male
# Age                          60.5
# SibSp                           0
# Parch                           0
# Ticket                       3701
# Fare                       7.8958
# Cabin                         NaN
# Embarked                        S
# Name: 152, dtype: object

# %%
df[df['Fare'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ## Handleing NaN values of 'Cabin' column

# %% [markdown]
# There are way too many NaNs to deal with in the 'Cabin' column, so I will just drop it. LOL

# %%
df.drop(columns='Cabin', axis=1, inplace=True)
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex        Age  SibSp  Parch              Ticket      Fare Embarked
# 0      male  34.500000      0      0              330911    7.8292        Q
# 1    female  47.000000      1      0              363272    7.0000        S
# 2      male  62.000000      0      0              240276    9.6875        Q
# 3      male  27.000000      0      0              315154    8.6625        S
# 4    female  22.000000      1      1             3101298   12.2875        S
# ..      ...        ...    ...    ...                 ...       ...      ...
# 413    male  24.525104      0      0           A.5. 3236    8.0500        S
# 414  female  39.000000      0      0            PC 17758  108.9000        C
# 415    male  38.500000      0      0  SOTON/O.Q. 3101262    7.2500        S
# 416    male  24.525104      0      0              359309    8.0500        S
# 417    male  24.525104      1      1                2668   22.3583        C
#
# [418 rows x 10 columns]

# %% [markdown]
# # **3. Find the percentage of men and women who survived. Plot them in a pie cahrt.**

# %% [markdown]
# ## Finding the Percentage

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

data = pd.read_csv("C:\Musfique's Folder\Tasu\Lab Tasu/test.csv", skipinitialspace=True)

males = data[data['Sex']=='male']['Embarked'].value_counts()
females = data[data['Sex']=='female']['Embarked'].value_counts()

figure1 = plt.bar(range(len(males)), males, align='edge', width=0.4, label='Male')
figure2 = plt.bar(range(len(females)), females, align='edge', width=-0.4, label='Female')
plt.legend()
plt.xticks(np.arange(len(males)), rotation=0)
plt.title("Third class survivors")

plt.show()
males
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\M'
# <>:5: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\PC\AppData\Local\Temp\ipykernel_23392\4288141448.py:5: SyntaxWarning: invalid escape sequence '\M'
#   data = pd.read_csv("C:\Musfique's Folder\Tasu\Lab Tasu/test.csv", skipinitialspace=True)
# Embarked
# S    182
# C     62
# Q     22
# Name: count, dtype: int64
